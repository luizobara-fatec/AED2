# %%
# !pip install passlib
# Out:
# Requirement already satisfied: passlib in c:\users\luizobara\anaconda3\lib\site-packages (1.7.4)

# %%
from passlib.hash import pbkdf2_sha256 as cryp

# %%
class User:
    def __init__(self, name, lastname, email, password):
        self.__name = name
        self.__lastname = lastname
        self.__email = email
        self.__password = self.encrypt_password(password)

    def get_name(self):
        return self.__name

    def get_lastname(self):
        return self.__lastname

    def get_email(self):
        return self.__email

    def set_name(self, name):
        self.__name = name

    def set_lastname(self, lastname):
        self.__lastname = lastname

    def set_email(self, email):
        self.__email = email

    def encrypt_password(self, password):
        return cryp.hash(password, rounds=1000, salt_size=10)

    def __str__(self):
        return (f'Nome: {self.get_name()}\nSobrenome: {self.get_lastname()}\nEmail: {self.get_email()} \nSenha Criptografada: {self.__password}')

    def check_password(self, password):
        return cryp.verify(password, self.__password)

# %%
user_01 = User('Luiz', 'Obara', 'luizobara@gmail.com', 'senha teste')
print(user_01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 user_01 = User('Luiz', 'Obara', 'luizobara@gmail.com', 'senha teste')
# ----> 2 print(user_01)
#
# Cell In[18], line 30, in User.__str__(self)
#      29 def __str__(self):
# ---> 30     return (f'Nome: {self.get_name()}\nSobrenome: {self.get_lastname()}\nEmail: {self.get_email()} \nSenha Criptografada: {self.__password}')
#
# Cell In[18], line 9, in User.get_name(self)
#       8 def get_name(self):
# ----> 9     return self.__name
#
# AttributeError: 'User' object has no attribute '_User__name'

# %%
user_01.check_password('')
# Out:
# False

# %%
user_01.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 user_01.name
#
# AttributeError: 'User' object has no attribute 'name'
